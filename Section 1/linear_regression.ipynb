# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('cost_revenue_clean.csv')
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = pd.DataFrame(data['production_budget_usd'])
y = pd.DataFrame(data['worldwide_gross_usd'])

# %%
plt.scatter(X, y, alpha=0.3)

# %%
regression = LinearRegression().fit(X, y)

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red')
plt.ylim(0, y.max()[0]*1.02)
plt.xlim(0, X.max()[0]*1.02)
plt.ylabel('Wolrdwide gross revenue ($)')
plt.xlabel('Production budget ($)')
plt.legend(['prediction', 'data'])

# %%
plt.title('Zooming in prediction intercept with x and y axes')
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red')
plt.ylim(-8e6, 1e6)
plt.xlim(0, 3e6)
plt.ylabel('Wolrdwide gross revenue ($)')
plt.xlabel('Production budget ($)')
plt.legend(['prediction', 'data'])
